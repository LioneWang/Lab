# %%
import torch
from torch import nn
import torchvision
from torchvision import transforms
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
torch.__version__
# Out:
# '2.10.0'

# %%
y=np.array([[1,2],[3,4],[5,6]])
x=np.array([1,2,3])
plt.plot(x,y)
# Out:
# [<matplotlib.lines.Line2D at 0x134ff6a10>,
#  <matplotlib.lines.Line2D at 0x134ff6b60>,
#  <matplotlib.lines.Line2D at 0x134ff6cb0>]
